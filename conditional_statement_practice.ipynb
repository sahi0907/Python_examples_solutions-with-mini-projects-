# %% [markdown]
# <a href="https://colab.research.google.com/github/sahi0907/Python_examples_solutions-with-mini-projects-/blob/main/conditional_statement_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number = 5
if number > 0:
  print("the no is positive")
# Out:
# the no is positive

# %%
age = 16
if age >=18:
  print("you are eligible to vote")
else:
  print("you are not eligible to vote")
# Out:
# you are not eligible to vote

# %%
#cheak weather number is even or odd
num = 2
if num % 2 == 0 :
  print("Num is even")
else:
  print("Num is odd")
# Out:
# Num is even

# %%
marks = int(input("enter your marks :"))
if marks >= 90 :
  print("grade - A")
elif marks >=80 :
  print("grade - B")
elif marks >= 70 :
  print("grade - c")
else:
  print("you are fail")
# Out:
# enter your marks :65
# you are fail

# %%
# state weather number positive or negative
num = -3
if num > 0 :
  print("positive")
elif num < 0 :
  print("negative")
else :
  print("zero")
# Out:
# negative

# %%
#find the large number
a = 5
b = 10
if a > b :
  print("a is large number")
else :
  print("b is large number")
# Out:
# b is large number

# %%
age = 18
if age  >= 18 :
  print("you can drive")
else:
  print("you can't drive")
# Out:
# you can drive

# %%
#cheak wether year is leap year
year= 2024
if year % 4 == 0 :
  print("leap year")
else :
  print("not a leap year")
# Out:
# leap year

# %%
# cheak if number is divisible by 5
num = 17
if num % 5 == 0 :
  print("divisible by 5")
else:
  print("not divisible by 5")
# Out:
# not divisible by 5

# %%
#cheak the tempreture
temp = int(input("enter the tempreture : "))
if temp >=30 :
  print("it's hot 🔥")
elif temp >=20 :
  print("it's normal")
else :
  print("it's cold as ice ")
# Out:
# enter the tempreture : 35
# it's hot 🔥

# %%
# find the largest of three number
a = 10
b = 12
c = 15
if a > b and a > c :
  print ("a is a largest number ")
elif b > a and b > c :
  print("b is a largest numbe ")
else :
  print("c is a largest number")
# Out:
# c is a largest number

# %%
number = 20
if number % 5 == 0 and number % 10 == 0:
  print("divisible by 5 and 10")
else :
  print("not divisible by 5 and 10")
# Out:
# divisible by 5 and 10

# %%
# between 10 and 50
num = int(input("enter the number :"))
if num >=10 and num <= 50 :
  print("number is between 10 & 50")
else :
  print("number is not between 10 & 50")
# Out:
# enter the number :55
# number is not between 10 & 50

# %%
from IPython.core.compilerop import operator
#simple calculator
a = int(input("enter the first num :"))
b = int(input("enter the second num :"))
operator = input("enter the operator :")
if operator == '+' :
  print(a + b)
elif operator == '-':
  print(a - b )
elif operator == '*':
  print( a * b )
elif operator == '/':
  print( a / b)
else :
  print('invalid operator')
# Out:
# enter the first num :120050
# enter the second num :67
# enter the operator :/
# 1791.7910447761194

# %%
#electricity bill system
unit = 260
bill = 0
if unit <= 100:
  bill = 0
elif unit <= 200:
  bill = (unit - 100) * 5
else :
  bill = (100 * 5) + (unit - 200) * 10
  print("total bill : ", bill)
# Out:
# total bill :  1100

# %%
# atm pin access
correct_pin = int(input("enter the correct pin :"))
entered_pin = int(input("enter the enterd pin :"))
if correct_pin == entered_pin :
  print("access granted")
else :
  print("access denied")
# Out:
# enter the correct pin :5516
# enter the enterd pin :5516
# access granted

# %%
#login system
username = "Sahil"
password = "12345"
if username == "Sahil" and password == "12345" :
  print("login successfully")
else:
  print("login failed")
# Out:
# login successfully

# %%
# password strenth cheaker
password = input("enter the password")
if len(password) <6 :
  print("weak password")
elif len(password) <= 10 :
  print("medium password")
else:
  print("strong password")
# Out:
# enter the passwordsahil
# weak password
