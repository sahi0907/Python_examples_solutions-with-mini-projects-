# %% [markdown]
# <a href="https://colab.research.google.com/github/sahi0907/Python_examples_solutions-with-mini-projects-/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# string indexing
name = "python"
print(name[0])
# Out:
# p

# %%
print(name[3])
# Out:
# h

# %%
print(name[1])
# Out:
# y

# %%
print(name[-2])
# Out:
# o

# %%
print(name[5])
# Out:
# n

# %%
s = "programming"
s[-3]
s[0]
s[-5]
s[6]
s[-1]
# Out:
# 'g'

# %%
#string slicing
Text = "pythonprogramming"
Text[0:3]
# Out:
# 'pyt'

# %%
Text[0:6]
# Out:
# 'python'

# %%
Text[6:]
# Out:
# 'programming'

# %%
Text[:6]
# Out:
# 'python'

# %%
#step slicing
Text[::6]
# Out:
# 'ppm'

# %%
Text[6::]
# Out:
# 'programming'

# %%
Text[::-1]
# Out:
# 'gnimmargorpnohtyp'

# %%
#operator string formatting
name = "rahul"
age = 27
print("my name is %s and my age is %d" %(name, age))
# Out:
# my name is rahul and my age is 27

# %%
#str.format
name = "riya"
salary = "100000"

print("Hello I am {}, my salary is upto {}" .format(name, salary))
# Out:
# Hello I am riya, my salary is upto 100000

# %%
#index based format
print("my name is {0}, my roll no is {1}" .format("sahil", 53))
# Out:
# my name is sahil, my roll no is 53

# %%
#keyword based formatting
print("user : {name}, role : {role}" .format(name = "admin", role = "manager"))
# Out:
# user : admin, role : manager

# %%
# f string
name = "suman"
score = 92

print(f"name : {name}, score: {score}")
# Out:
# name : suman, score: 92

# %%
Ai = "hii sameer ,how are you"
client = "hey i am fine and you"
print(f"ai:{Ai},client:{client}")
# Out:
# ai:hii sameer ,how are you,client:hey i am fine and you

# %%
#practice quetions strings
#print the 1st , 5th and last character
s = "programming"
s[0]
# Out:
# 'p'

# %%
s[5]
# Out:
# 'a'

# %%
s[-1]
# Out:
# 'g'

# %%
#print the character at index -5
s[-5]
# Out:
# 'm'

# %%
#print the middle char of string
mid =len(s)//2
print(s[mid])
# Out:
# a

# %%
#print even indxes
s[::2]
# Out:
# 'pormig'

# %%
#print all char odd indexes
s[1::2]
# Out:
# 'rgamn'

# %%
#extract python form string
t="pythonprogramming"
t[:6]
# Out:
# 'python'

# %%
t[-11::]
# Out:
# 'programming'

# %%
#remove first 3 char from string
t[-14::]
# Out:
# 'honprogramming'

# %%
#remove last four char
t[0:13]
# Out:
# 'pythonprogram'

# %%
#reverse the string
t[::-1]
# Out:
# 'gnimmargorpnohtyp'

# %%
#print every second char
t[::2]
# Out:
# 'ptopormig'

# %%
#print every third char
t[::3]
# Out:
# 'phpgmn'

# %%
#print reverse -2
t[::-2]
# Out:
# 'gimropotp'

# %%
t[1:-2:2]
# Out:
# 'yhnrgam'
